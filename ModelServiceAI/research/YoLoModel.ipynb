# %%
from ultralytics import YOLO
import cv2

model = YOLO(model = "yolo26n.pt",
             task = "detection")

result = model.predict("../data/img.png")

# %%
import time

time_start = time.time()
result = model.predict("../data/img.png")
print("Time: ", time.time() - time_start)
# Out:
# image 1/1 /home/alex/dev/python/TrackVision/ModelServiceAI/research/../data/img.png: 448x640 4 persons, 93.0ms
# Speed: 3.0ms preprocess, 93.0ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
# Time:  0.11411094665527344

# %%
print(model)
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (2): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
# ...
